# %% [markdown]
# <a href="https://colab.research.google.com/github/carvatreek25/teste_2/blob/pasta/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 9. Salvar o dataframe como parquet
df_video.write.mode("overwrite").parquet("videos-preparados-parquet")
