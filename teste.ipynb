# %%
                                    def registrar_evento(evento, severidade='baixa', **kwargs):
                    registro = {'evento': evento, 'severidade': severidade}
                    registro.update(kwargs)
                                return registro
                    # Testes
                    print(registrar_evento('login_falhou'))
                              print(registrar_evento(
                    'disco_cheio',
                                 severidade='alta',
                    servidor='srv-01',
                    disco='/dev/sda',
                    uso_percentual=98
                    ))
# Out:
#   Cell In[1], line 2
#     registro = {'evento': evento, 'severidade': severidade}
#     ^
# IndentationError: expected an indented block after function definition on line 1
